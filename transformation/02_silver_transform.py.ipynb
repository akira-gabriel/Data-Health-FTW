# %%
df = spark.table("workspace.bronze.gho_raw")

# %%
display(df)

# %%
df.columns

# %%
df.printSchema()

# %%
df = df.select("SpatialDim", "ParentLocationCode", "TimeDim", "IndicatorCode", "NumericValue", "Low", "High")

# %%
df.display()
